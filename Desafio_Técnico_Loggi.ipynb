# %% [markdown]
# <a href="https://colab.research.google.com/github/cosez/CheckSignin/blob/main/Desafio_T%C3%A9cnico_Loggi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio Técnico Loggi - Igor Costa da Silva Estevão de Azevedo
# <h4>
#     Nesse notebook as perguntas do desafio técnico são respondidas através de uma análise feita a partir des dados retirados das tabelas do desafio que foram unidas e criadas utillizando Oracle Live SQL.
# </h4>
#
# > <p>As respostas foram obtidas utilizando SQL e geradas em csv que serão mostradas em DataFrame neste notebook</p>

# %% [markdown]
# Importando a biblioteca necessária para manipularmos os dataframes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Primeira Questão:

# %% [markdown]
# > Como podemos ver temos abaixo a média de nota por matéria e trimestre.

# %%
df_media_materia_trim = pd.read_csv('Primeira Questão.csv')
df_media_materia_trim
# Out:
#     ID_MATERIA                       DESCRICAO  AVG(NOTA)  \
# 0            0                              -         1.3
# 1            1            Logica Computacional        5.8
# 2            1            Logica Computacional        1.7
# 3            1            Logica Computacional        5.3
# 4            2   Nocoes Basicas de Estatistica        8.5
# 5            2   Nocoes Basicas de Estatistica        5.8
# 6            2   Nocoes Basicas de Estatistica        2.0
# 7            2   Nocoes Basicas de Estatistica        1.1
# 8            2   Nocoes Basicas de Estatistica        8.9
# 9            3     Nocoes Basicas de Analytics        0.3
# 10           3     Nocoes Basicas de Analytics        6.2
# 11           3     Nocoes Basicas de Analytics        8.7
# 12           3     Nocoes Basicas de Analytics        0.7
# 13           3     Nocoes Basicas de Analytics        7.4
# 14           3     Nocoes Basicas de Analytics        6.1
# ...

# %% [markdown]
# > Caso a verdadeira intenção seja a média das notas por materia e semestre teremos:

# %%
df_media_materia_trim['AVG(NOTA)'].mean()
# Out:
# 4.853191489361703

# %% [markdown]
# ### Segunda Questão:

# %% [markdown]
# > Mostramos agora o dataframe contendo a média por alunos e trimestre

# %%
df_media_aluno_trim = pd.read_csv('Segunda Questão.csv')
df_media_aluno_trim
# Out:
#     ID_ESTUDANTE                NOME  AVG(NOTA) DATA_INICIO_TRIMESTRE
# 0              1     Francisco Alves   5.800000             01-APR-17
# 1              1     Francisco Alves   8.500000             01-JUL-17
# 2              1     Francisco Alves   1.700000             01-JAN-19
# 3              1     Francisco Alves   1.100000             01-JUL-19
# 4              1     Francisco Alves   8.000000             01-JUL-21
# 5              2      Giovana Mendes   8.700000             01-JAN-19
# 6              2      Giovana Mendes   3.600000             01-JAN-20
# 7              2      Giovana Mendes   2.400000             01-APR-20
# 8              3       Serdio Duarte   1.300000             01-JAN-17
# 9              3       Serdio Duarte   9.400000             01-JUL-17
# 10             3       Serdio Duarte   7.700000             01-JUL-19
# 11             3       Serdio Duarte   2.200000             01-JAN-20
# ...

# %% [markdown]
# > Caso a verdadeira intenção seja a média das médias de notas por aluno e semestre teremos:

# %%
df_media_aluno_trim['AVG(NOTA)'].mean()
# Out:
# 4.886742424242427

# %% [markdown]
# ### Terceira e Quarta questões: Qual professor reprova/aprova mais?

# %% [markdown]
# * 3ª: Professor Gianluca Marino
# * 4ª: Professora Astrogilda Neves

# %%
df_porcentagem_aprv = pd.read_csv('Terceira Questão.csv')
df_porcentagem_aprv
# Out:
#    ID_PROFESSOR              NOME  PCT_APROV
# 0             5  Gianluca Marino        0.22
# 1             1     João da Silva       0.33
# 2             2     Maria Antônia       0.36
# 3             4   Aprilio Maldivo       0.38
# 4             3  Astrogilda Neves       0.42

# %% [markdown]
# Temos acima a porcentagem de aprovação de cada professor, o que indica que 1 - pct_aprov indica a porcentagem de reprovação por professor. Assim podendo concluir as respostas das questões 3 e 4.

# %% [markdown]
# ### Quinta questão: Qual curso tem menor desvio padrão de notas?

# %%
df_Quinta_Questao = pd.read_csv('Quinta questão.csv')
df_Quinta_Questao
# Out:
#                  CURSO  ROUND(STDDEV(NOTA),2)
# 0          Estatística                   3.18
# 1  Matemática Aplicada                   3.05

# %% [markdown]
# > Como podemos observar acima o curso que possui o menor desvio padrão é o de Matemática aplicada.

# %% [markdown]
# ### Sexta questão: Qual aluno tem menor desvio padrão de notas?

# %%
df_Sexta_Questao = pd.read_csv('Sexta Questão.csv')
df_Sexta_Questao
# Out:
#                   NOME  DESVIO_PADRAO
# 0        Antonio Silva           0.00
# 1      Geogirna Coelho           0.31
# 2      Henrique Macedo           1.87
# 3    Fernando Silveira           2.03
# 4         Helio Castro           2.62
# 5       Natalia Soares           3.15
# 6       Giovana Mendes           3.35
# 7      Francisco Alves           3.46
# 8        Serdio Duarte           3.49
# 9         Maria Flores           3.55
# 10  Guilherme Custodio           4.12
# 11        Paula Mendel           4.47

# %%
sns.catplot(y="NOME", x="DESVIO_PADRAO", data=df_Sexta_Questao, kind="bar")

# %% [markdown]
# > Observando a tabela obtida através de funções SQL temos que Antonio Silva é o aluno com menor desvio padrão das notas. No entando, ele só recebeu uma nota na tabela de notas.

# %% [markdown]
# ### Sétima questão:

# %%
df_Setima_Questao = pd.read_csv('Sétima Questão PERC.csv')
df_Setima_Questao
# Out:
#                          DESCRICAO  PERC_FALTAS
# 0                               -          0.02
# 1        Gerenciamento de Projetos         0.06
# 2   Algoritmos de Machine Learning         0.07
# 3               Programacao Python         0.07
# 4             Logica Computacional         0.08
# 5    Nocoes Basicas de Estatistica         0.09
# 6    Introducao aos banco de dados         0.09
# 7                    Programacao R         0.10
# 8      Projeto em Ciencia de Dados         0.11
# 9             Arquitetura de Dados         0.12
# 10     Nocoes Basicas de Analytics         0.19

# %%
_ = sns.catplot(y="DESCRICAO", x="PERC_FALTAS", data=df_Setima_Questao, kind="bar")
_ = plt.ylabel('Matéria')

# %% [markdown]
# Observando o DF vemos que a disciplina que possui o maior percentual de faltas é Noções básicas de analytics.
# > OBS: Para esta questão e a anterior calculamos utilizando a função SUM(faltas) para descobrir o número total de faltas e assim ter uma porcentagem.

# %% [markdown]
# ### Oitava Questão: Qual aluno tem mais de 25% de faltas?

# %%
df_Oitava_Questao = pd.read_csv('Oitava Questão.csv')
df_Oitava_Questao
# Out:
#                   NOME  PERC_FALTAS
# 0        Antonio Silva         0.03
# 1       Giovana Mendes         0.04
# 2         Maria Flores         0.06
# 3      Geogirna Coelho         0.07
# 4      Francisco Alves         0.08
# 5    Fernando Silveira         0.08
# 6         Paula Mendel         0.08
# 7       Natalia Soares         0.08
# 8         Helio Castro         0.11
# 9        Serdio Duarte         0.11
# 10     Henrique Macedo         0.11
# 11  Guilherme Custodio         0.13

# %%
sns.set_context('paper')
sns.catplot(y="NOME", x="PERC_FALTAS", data=df_Oitava_Questao, kind="bar")

# %% [markdown]
# > Como podemos ver, nenhum aluno possui mais que 25% de faltas.

# %% [markdown]
# ### Nona questão:

# %% [markdown]
# > Inicialmente podemos notar que temos uma instância no atributo materia que contém o valor 0, poderíamos ter a retirado do nosso dataset para evitar uma uma "sujeita" nos dados. No dataset 'Tabela de notas com dados completos.csv' retiramos o id_materia e o substituimos pela descrição e utilizamos um ' - ' podendo também ter transformado em Null, mas sendo necessário tratar em uma análise posterior.

# %%
df_completa = pd.read_csv('Tabela de notas com os dados completos.csv')
df_completa[df_completa['DESCRICAO'] == ' - ']
# Out:
#       NOME_ALUNO NOME_PROFESSOR  NOTA  FALTAS  NRO_TURMA                CURSO  \
# 0  Serdio Duarte  João da Silva   1.3       6         20  Matemática Aplicada
#
#   DATA_INICIO_TRIMESTRE DATA_ADMISSAO_ESTUDANTE DATA_ADMISSAO_PROFESSOR  \
# 0             01-JAN-17               01-JAN-20               01-APR-17
#
#   DESCRICAO NOTA_MINIMA
# 0        -           -

# %% [markdown]
# > Temos também que a data de admissão do professor em alguns caso nas tabela de notas se encontra depois do fim do trimestre o que impossibilitaria o professor de lecionar no semestre indicado pela tabela de notas.
#  * Utilizamos 1 para indicar como verdade para o caso acima.

# %%
df_datas = pd.read_csv('datas de admissão depois do inicio do semestre.csv')
df_datas
# Out:
#                 NOME DATA_ADMISSAO DATA_INICIO_TRIMESTRE  DATA_INCORRETA
# 0    Aprilio Maldivo     01-SEP-15             01-JUL-17               0
# 1    Aprilio Maldivo     01-SEP-15             01-JUL-18               0
# 2    Aprilio Maldivo     01-SEP-15             01-OCT-18               0
# 3    Aprilio Maldivo     01-SEP-15             01-OCT-19               0
# 4    Aprilio Maldivo     01-SEP-15             01-OCT-19               0
# 5    Aprilio Maldivo     01-SEP-15             01-OCT-20               0
# 6    Aprilio Maldivo     01-SEP-15             01-JAN-21               0
# 7    Aprilio Maldivo     01-SEP-15             01-APR-21               0
# 8      João da Silva     01-APR-17             01-JAN-17               1
# 9      João da Silva     01-APR-17             01-JAN-19               0
# 10     João da Silva     01-APR-17             01-JUL-19               0
# 11     João da Silva     01-APR-17             01-OCT-19               0
# ...

# %%
sns.countplot(x="DATA_INCORRETA",data=df_datas)
plt.ylabel('# Ocorrências')
# Out:
# Text(0, 0.5, '# Ocorrências')

# %% [markdown]
# Neste gráfico podemos ver que a quantidade de dados com as datas "incorretas" seguindo as condições indicadas é quase mais que 1/3 do nosso dataset.

# %% [markdown]
# Fazendo uma análise mais superficial do nosso dataset completo temos:

# %%
df_completa.head(2)
# Out:
#         NOME_ALUNO    NOME_PROFESSOR  NOTA  FALTAS  NRO_TURMA  \
# 0    Serdio Duarte     João da Silva   1.3       6         20
# 1  Geogirna Coelho  Astrogilda Neves   0.3       6         20
#
#                  CURSO DATA_INICIO_TRIMESTRE DATA_ADMISSAO_ESTUDANTE  \
# 0  Matemática Aplicada             01-JAN-17               01-JAN-20
# 1  Matemática Aplicada             01-JAN-17               01-JAN-20
#
#   DATA_ADMISSAO_PROFESSOR                    DESCRICAO NOTA_MINIMA
# 0               01-APR-17                           -           -
# 1               01-FEB-20  Nocoes Basicas de Analytics           6

# %%
df_completa.tail(1)
# Out:
#            NOME_ALUNO NOME_PROFESSOR  NOTA  FALTAS  NRO_TURMA  \
# 48  Fernando Silveira  João da Silva   4.4       6         21
#
#                   CURSO DATA_INICIO_TRIMESTRE DATA_ADMISSAO_ESTUDANTE  \
# 48  Matemática Aplicada             01-OCT-21               01-JUN-20
#
#    DATA_ADMISSAO_PROFESSOR             DESCRICAO NOTA_MINIMA
# 48               01-APR-17  Arquitetura de Dados           8

# %%
df_completa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NOME_ALUNO               49 non-null     object
#  1   NOME_PROFESSOR           49 non-null     object
#  2   NOTA                     49 non-null     float64
#  3   FALTAS                   49 non-null     int64
#  4   NRO_TURMA                49 non-null     int64
#  5   CURSO                    49 non-null     object
#  6   DATA_INICIO_TRIMESTRE    49 non-null     object
#  7   DATA_ADMISSAO_ESTUDANTE  49 non-null     object
#  8   DATA_ADMISSAO_PROFESSOR  49 non-null     object
#  9   DESCRICAO                49 non-null     object
#  10  NOTA_MINIMA              49 non-null     object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 4.3+ KB

# %% [markdown]
# Podemos ver que temos atributos que podem ser transformados em variáveis categóricas, como por exemplo nro_turma.

# %%
df_completa.describe()
# Out:
#             NOTA     FALTAS  NRO_TURMA
# count  49.000000  49.000000  49.000000
# mean    4.885714   6.040816  16.632653
# std     3.111939   2.457634   4.080920
# min     0.200000   1.000000  12.000000
# 25%     2.200000   4.000000  13.000000
# 50%     5.200000   6.000000  20.000000
# 75%     7.900000   8.000000  21.000000
# max     9.800000  10.000000  21.000000

# %% [markdown]
# E por fim temos nossas medidas descritivas.
